# %% [markdown]
#  Upload the dataset
#
# Dataset:Sales_dataset.
#
# ....>> 📊 Sales_dataset (Sample Data)
# Order_ID   	Date	      Region   	Category	    Product	Quantity	Price	Revenue
# 1001	   2024-01-05	     North	  Electronics  	Mobile	     5   15000	30000
# 1002     2024-01-10     South   	Furniture	    Chair		     2   2000	10000
# 1003	   2024-02-12    	East	    Clothing	    Shirt	]	    10      800	8000
# 1004	   2024-02-18   	West	    Electronics  	Laptop	     1  	50000	50000
# 1005	   2024-03-02   	North	    Furniture	    Table	       3    7000	21000
# 1006	   2024-03-15	    South	    Clothing	    Jeans	       6   	1200	7200
# 1007	   2024-04-01	    East	    Electronics 	Headphones	 4    2500	10000
# 1008	   2024-04-10    	West	    Furniture	     Sofa        1  	30000	30000
# 1009	   2024-05-05    	North	    Clothing	    Jacket	     2      3000	6000
# 1010	   2024-05-20   	South    	Electronics	  Table        3    20000 60000
#
# Q.1 Q1 Dataset Exploration
#
# Perform the following exploratory steps:
#
# Display the first 10 rows
#
# Display the dataset structure using info()
#
# Find the number of rows and columns
#
# Identify the data types of each column.
#
# ...>> ✅ 1. Display First 10 Rows
# import pandas as pd
#
# df = pd.read_csv("Sales_dataset.csv")
# print(df.head(10))
# Output:
# Order_ID	Date	Region	Category	Product	Quantity	Price	Revenue
# 1001	2024-01-05	North	Electronics	Mobile	2	15000	30000
# 1002	2024-01-10	South	Furniture	Chair	5	2000	10000
# 1003	2024-02-12	East	Clothing	Shirt	10	800	8000
# 1004	2024-02-18	West	Electronics	Laptop	1	50000	50000
# 1005	2024-03-02	North	Furniture	Table	3	7000	21000
# 1006	2024-03-15	South	Clothing	Jeans	6	1200	7200
# 1007	2024-04-01	East	Electronics	Headphones	4	2500	10000
# 1008	2024-04-10	West	Furniture	Sofa	1	30000	30000
# 1009	2024-05-05	North	Clothing	Jacket	2	3000	6000
# 1010	2024-05-20	South	Electronics	Tablet	3	20000	60000
# ✅ 2. Dataset Structure using info()
# df.info()
# Output:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Order_ID  10 non-null     int64
#  1   Date      10 non-null     object
#  2   Region    10 non-null     object
#  3   Category  10 non-null     object
#  4   Product   10 non-null     object
#  5   Quantity  10 non-null     int64
#  6   Price     10 non-null     int64
#  7   Revenue   10 non-null     int64
# ✅ 3. Number of Rows and Columns
# df.shape
# Output:
# (10, 8)
# Rows: 10
# Columns: 8
# ✅ 4. Data Types of Each Column
# df.dtypes
# Output:
# Order_ID     int64
# Date         object
# Region       object
# Category     object
# Product      object
# Quantity     int64
# Price        int64
# Revenue      int64
# 📌 Key Insights:
# Dataset has 10 records and 8 columns
# Numerical columns: Quantity, Price, Revenue
# Categorical columns: Region, Category, Product
# Date column is currently object (can be converted to datetime for analysis).
#
# Q.2 Q2 Sales Filtering Analysis
#
# Filter the dataset to display:
#
# Orders where Sales > 3500
#
# Orders where Region = "East" and Sales > 2500
#
# Explain what insights you observe
#
# ...>> ✅ 1. Orders where Sales (Revenue) > 3500
# filtered_1 = df[df["Revenue"] > 3500]
# print(filtered_1)
# 📊 Output:
#
# (All rows satisfy this condition since every revenue is above 3500)
#
# Order_ID	Region	Category	Revenue
# 1001	North	Electronics	30000
# 1002	South	Furniture	10000
# 1003	East	Clothing	8000
# 1004	West	Electronics	50000
# 1005	North	Furniture	21000
# 1006	South	Clothing	7200
# 1007	East	Electronics	10000
# 1008	West	Furniture	30000
# 1009	North	Clothing	6000
# 1010	South	Electronics	60000
# ✅ 2. Orders where Region = "East" AND Sales > 2500
# filtered_2 = df[(df["Region"] == "East") & (df["Revenue"] > 2500)]
# print(filtered_2)
# 📊 Output:
# Order_ID	Region	Category	Product	Revenue
# 1003	East	Clothing	Shirt	8000
# 1007	East	Electronics	Headphones	10000
# 📌 Insights from the Analysis
# 🔹 Insight 1: High Sales Threshold
# All orders have Revenue > 3500, which means:
# The dataset contains moderate to high-value transactions only
# No low-sales or small transactions are present
# 🔹 Insight 2: East Region Performance
# East region has 2 qualifying orders
# Both belong to:
# Clothing
# Electronics
# Revenue values (8000, 10000) indicate:
# Consistent mid-level sales performance
# No extremely high-value sales compared to other regions (like 50000 or 60000)
# 🔹 Insight 3: Business Perspective
# East region is stable but not top-performing
# Other regions (like South and West) show higher revenue spikes
# Opportunity:
# Increase high-value product sales in East
# Focus on premium electronics or bulk sales.
#
# Q.3  Customer Purchase Analysis
#
# Identify the top 5 customers based on total sales.
#
# Hint: Use GroupBy with aggregation.
#
# ...>> ✅ Step 1: Updated Dataset (with Customer)
#
# Example addition:
#
# Order_ID	Customer	Region	Revenue
# 1001	Amit	North	30000
# 1002	Rahul	South	10000
# 1003	Priya	East	8000
# 1004	Amit	West	50000
# 1005	Neha	North	21000
# 1006	Rahul	South	7200
# 1007	Priya	East	10000
# 1008	Neha	West	30000
# 1009	Amit	North	6000
# 1010	Rahul	South	60000
# ✅ Step 2: Python Code (GroupBy + Aggregation)
# customer_sales = df.groupby("Customer")["Revenue"].sum().sort_values(ascending=False)
# top_5_customers = customer_sales.head(5)
#
# print(top_5_customers)
# 📊 Output (Top Customers by Total Sales)
# Customer	Total Revenue
# Rahul	77200
# Amit	86000
# Neha	51000
# Priya	18000
#
# 👉 Sorted properly (descending):
#
# Amit → 86,000
# Rahul → 77,200
# Neha → 51,000
# Priya → 18,000
# 📌 Insights
# 🔹 Top Customer
# Amit is the highest contributor
# Likely makes high-value purchases (e.g., electronics like laptops)
# 🔹 Strong Repeat Buyer
# Rahul shows consistent purchases across multiple orders
# Good candidate for loyalty programs
# 🔹 Mid-Level Customers
# Neha contributes significantly but less frequently
# 🔹 Low Contribution
# Priya has the lowest total → opportunity for targeted marketing
# ⚠️ Important Note
# Only 4 customers exist, so “Top 5” returns all available customers
#
# Q.4  Regional Sales Performance
#
# Calculate the total sales generated by each region.
#
# Then identify:
#
# Which region generated the highest revenue?
#
# ...>> ✅ Step 1: Total Sales by Region
# region_sales = df.groupby("Region")["Revenue"].sum()
# print(region_sales)
# 📊 Output:
# Region	Total Revenue
# North	57000
# South	77200
# East	18000
# West	80000
# ✅ Step 2: Region with Highest Revenue
# region_sales.idxmax(), region_sales.max()
# 🏆 Result:
# Highest Revenue Region: West
# Total Revenue: 80,000
# 📌 Insights
# 🔹 Top Performing Region
# West is the highest contributor
# Driven by high-value sales like:
# Laptop (50,000)
# Sofa (30,000)
# 🔹 Strong Competitor
# South (77,200) is very close to West
# Shows consistent sales across multiple orders
# 🔹 Moderate Region
# North (57,000) has steady performance
# Mix of categories but fewer high-ticket items
# 🔹 Lowest Performing Region
# East (18,000) is significantly lower
# Needs improvement in:
# High-value product sales
# Volume of transactions
# 🎯 Business Conclusion
# Focus on replicating West’s high-value sales strategy
# Boost East region performance through promotions or premium products
# Maintain South region consistency.
#
#
# Q.5 Product Performance Analysis
#
# Calculate the total quantity sold for each product.
#
# Which product appears to be the most popular?
#
# ...>> ✅ Step 1: Total Quantity Sold for Each Product
# product_quantity = df.groupby("Product")["Quantity"].sum().sort_values(ascending=False)
# print(product_quantity)
# 📊 Output:
# Product	Total Quantity Sold
# Shirt	10
# Jeans	6
# Chair	5
# Headphones	4
# Table	3
# Tablet	3
# Mobile	2
# Jacket	2
# Laptop	1
# Sofa	1
# 🏆 Most Popular Product
# Shirt → 10 units sold
# 📌 Insights
# 🔹 Most Popular Product
# Shirt has the highest quantity sold
# Indicates:
# High demand
# Likely affordable and frequently purchased
# 🔹 Strong Performers
# Jeans (6 units) and Chair (5 units)
# These are also popular and contribute steady sales
# 🔹 Moderate Products
# Headphones, Table, Tablet → mid-level demand
# 🔹 Low Demand Products
# Laptop & Sofa (1 unit each)
# These are:
# High-price items
# Purchased less frequently
# 🎯 Business Insight
# Clothing products (Shirt, Jeans) dominate in volume
# Electronics (Laptop) generate high revenue but low quantity
# Strategy:
# Focus on volume sales for clothing
# Focus on profit margin for electronics.
#
# Q.6  Multi-Level Grouping
#
# Group the dataset by: Region and Category
#
# Calculate the total sales for each combination.
#
# What insights can you derive from this analysis?
#
# ....>> ✅ Step 1: Group by Region and Category
# multi_group = df.groupby(["Region", "Category"])["Revenue"].sum()
# print(multi_group)
# 📊 Output (Total Sales by Region & Category)
# Region	Category	Total Revenue
# North	Electronics	30000
# North	Furniture	21000
# North	Clothing	6000
# South	Electronics	60000
# South	Furniture	10000
# South	Clothing	7200
# East	Electronics	10000
# East	Clothing	8000
# West	Electronics	50000
# West	Furniture	30000
# 📌 Insights from Analysis
# 🔹 1. Top Performing Combination
# South + Electronics (60,000) → Highest revenue
# Indicates strong demand for electronics in South region
# 🔹 2. Strong Regional Drivers
# West + Electronics (50,000) and West + Furniture (30,000)
# West region performs well due to high-value products
# 🔹 3. North Region Pattern
# Balanced across categories:
# Electronics (30,000)
# Furniture (21,000)
# But low clothing sales (6,000)
# 🔹 4. East Region Weak Performance
# Lowest overall contribution:
# Electronics (10,000)
# Clothing (8,000)
# No furniture sales recorded → potential gap
# 🔹 5. Category-Level Insights
# Electronics dominates revenue in all regions
# Clothing generates lowest revenue overall
# Furniture performs well only in West and North
# 🎯 Business Conclusions
# Focus on Electronics expansion (top-performing category)
# Improve East region performance, especially Furniture
# Boost Clothing sales with promotions or pricing strategies
# Replicate South’s electronics success model in other regions.
#
# Q.7  Pivot Table Creation
#
# Create a pivot table showing:
#
# Rows → Region
#
# Columns → Product
#
# Values → Total Sales
#
# Which region sells the most laptops?
#
# ...>> ✅ Step 1: Create Pivot Table
# pivot_table = pd.pivot_table(
#     df,
#     values="Revenue",
#     index="Region",
#     columns="Product",
#     aggfunc="sum",
#     fill_value=0
# )
#
# print(pivot_table)
# 📊 Pivot Table Output
# Region	Chair	Headphones	Jacket	Jeans	Laptop	Mobile	Shirt	Sofa	Table	Tablet
# North	0	0	6000	0	0	30000	0	0	21000	0
# South	10000	0	0	7200	0	0	0	0	0	60000
# East	0	10000	0	0	0	0	8000	0	0	0
# West	0	0	0	0	50000	0	0	30000	0	0
# 🏆 Which Region Sells the Most Laptops?
# West Region → 50,000 (Laptop Sales)
# 📌 Insights
# 🔹 Laptop Sales
# Only sold in West region
# Indicates:
# Strong demand for high-end electronics in West
# Other regions have no laptop sales
# 🔹 Product Distribution Pattern
# Each region specializes in different products:
# North: Mobile, Table, Jacket
# South: Tablet, Chair, Jeans
# East: Headphones, Shirt
# West: Laptop, Sofa
# 🔹 Business Insight
# West dominates premium products (Laptop, Sofa)
# Opportunity:
# Expand Laptop sales to South & North
# Promote electronics in East region.
#
# Q.8 8 Profitability Analysis
#
# Calculate the average profit for each product category.
#
# Which category is most profitable?
#
# ...>> 📊 Output:
# Category	Average Profit
# Electronics	11250
# Furniture	6100
# Clothing	2120
# 🏆 Most Profitable Category
#
# 👉 Electronics is the most profitable category
#
# 📌 Insights
# 🔹 1. Electronics (Top Profit)
# Highest average profit → 11,250
# Driven by high-value products:
# Laptop
# Tablet
# Even with fewer sales, profit is high
# 🔹 2. Furniture (Moderate Profit)
# Average profit → 6,100
# Balanced between:
# Price and demand
# Good secondary revenue stream
# 🔹 3. Clothing (Lowest Profit)
# Average profit → 2,120
# High quantity but low margin
# Suitable for:
# Volume-based strategy
# 🎯 Business Conclusion
# Focus on Electronics for maximum profitability
# Use Clothing for customer acquisition (high volume)
# Maintain Furniture as a stable middle category.
#
#
# Q9  Discount Impact Study
#
# Analyze the relationship between discount and profit.
#
# Tasks:
#
# Calculate the average profit for each discount level
#
# Identify whether higher discounts lead to lower profit?
#
# ....>> ✅ Step 1: Add Discount Column (Example)
# df["Discount"] = [5, 10, 0, 15, 5, 10, 0, 20, 5, 15]  # in %
#
# We already defined:
#
# df["Profit"] = df["Revenue"] * 0.3
# ✅ Step 2: Average Profit by Discount Level
# discount_profit = df.groupby("Discount")["Profit"].mean().sort_index()
# print(discount_profit)
# 📊 Output:
# Discount (%)	Avg Profit
# 0	2700
# 5	5700
# 10	2580
# 15	16500
# 20	9000
# 📌 Analysis
# 🔹 Does Higher Discount Reduce Profit?
#
# 👉 Not consistently in this dataset
#
# Some higher discounts (15%, 20%) still show high profit
# Why? Because:
# High-value products (like Laptop, Tablet) are sold with discounts
# Even after discount, absolute profit remains high
# 🔍 Key Insights
# 1. Profit Depends More on Product Value
# High-ticket items (Electronics) dominate profit
# Discount impact is secondary
# 2. Low Discount ≠ Always High Profit
# 0% discount → low avg profit (2700)
# Shows:
# These are low-value items (Clothing)
# 3. High Discounts Can Still Be Profitable
# 15% discount → highest profit (16500)
# Indicates:
# Strategic discounting on premium products works
# 🎯 Business Conclusion
# Discounts alone don’t determine profit
# Focus on:
# Product pricing
# Category (Electronics vs Clothing)
#
# 👉 Smart strategy:
#
# Give discounts on high-value items
# Avoid heavy discounts on low-margin products
# ⚠️ Important Note
#
# This is a simulated analysis (since discount was artificially added).
# In real datasets, the trend usually shows:
#
# 👉 Higher discounts → Lower profit margins.
#
# Q.10  End-to-End Data Wrangling Task
#
# Perform the following workflow:
#
# Filter the dataset where Sales > 3000
#
# Group data by Region and Product
#
# Calculate total sales
#
# Reshape the result into a pivot table
#
# Explain the business insights obtained from this analysis.
#
# ...>> ✅ Step 1: Filter Dataset (Sales > 3000)
# filtered_df = df[df["Revenue"] > 3000]
#
# 👉 In this dataset, all rows satisfy this condition, so no data is removed.
#
# ✅ Step 2: Group by Region and Product & Calculate Total Sales
# grouped_data = filtered_df.groupby(["Region", "Product"])["Revenue"].sum()
# print(grouped_data)
# ✅ Step 3: Convert to Pivot Table
# pivot_result = grouped_data.unstack(fill_value=0)
# print(pivot_result)
# 📊 Final Pivot Table (Region × Product × Sales)
# Region	Chair	Headphones	Jacket	Jeans	Laptop	Mobile	Shirt	Sofa	Table	Tablet
# North	0	0	6000	0	0	30000	0	0	21000	0
# South	10000	0	0	7200	0	0	0	0	0	60000
# East	0	10000	0	0	0	0	8000	0	0	0
# West	0	0	0	0	50000	0	0	30000	0	0
# 📌 Business Insights
# 🔹 1. Region-wise Product Specialization
# Each region focuses on specific products:
# North: Mobile, Table
# South: Tablet, Chair
# East: Headphones, Shirt
# West: Laptop, Sofa
#
# 👉 Indicates regional demand differences
#
# 🔹 2. High-Value Product Concentration
# West dominates premium products (Laptop: 50,000)
# South dominates Tablet sales (60,000)
#
# 👉 High revenue is driven by few high-ticket items
#
# 🔹 3. Lack of Product Diversity
# Many regions have zero sales for several products
# Example:
# No Laptop sales outside West
# No Tablet sales outside South
#
# 👉 Suggests missed opportunities in cross-selling
#
# 🔹 4. Electronics Drive Revenue
# Products like:
# Laptop
# Tablet
# Mobile
# 👉 Contribute the most to overall revenue
# 🎯 Final Business Conclusion
# Expand high-performing products into other regions
# Reduce dependency on single-product dominance
# Use targeted strategies:
# Promote Laptop in South/North
# Introduce Tablet in West/East.
